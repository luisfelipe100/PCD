# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfelipe100/PCD/blob/main/PCD_Tarea1_Participacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Participación (2 puntos)
#
# - Aplicar la técnica de stem o lematización para analizar la frecuencia de palabras de esta obra

# %%
# !pip install gutenbergpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 7.7 MB/s eta 0:00:00
# ...
#   Created wheel for httpsproxy-urllib2: filename=httpsproxy_urllib2-1.0-py3-none-any.whl size=29250 sha256=436b48586e77be1ff8f1e59360bcd362da34a3f9ab926b6bfff41a39b1b6da30
#   Stored in directory: /root/.cache/pip/wheels/e6/5c/6b/790df3d7037e3d9aaf7a48d563626941f2f60198d2f1eef8d2
# Successfully built httpsproxy-urllib2
# ...

# %%
import gutenbergpy.textget
def obtener_libro(id = 2701):
    raw_book = gutenbergpy.textget.get_text_by_id(id) # with headers
    clean_book = gutenbergpy.textget.strip_headers(raw_book) # without headers
    return clean_book, raw_book

libro_limpio, libro = obtener_libro()

str_libro = libro_limpio.decode()
list_libro = str_libro.split("\n")
libro_filtrado = list(filter(None, list_libro))

import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt_tab')

def tokens(txt, idioma = 'english'):
    texto_limpio = re.sub(r'[^\w\s]', '', txt.lower())

    stop_words = set(stopwords.words(idioma))
    tokens = word_tokenize(texto_limpio)
    texto_filtrado = [word for word in tokens if word not in stop_words]
    return texto_filtrado

map_libro = list(map(tokens, libro_filtrado))

tokens = []
for token in map_libro:
    tokens.extend(token)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import pandas as pd
df = pd.DataFrame(tokens)
# Conteo de frecuencias sin uso de la técnica stem
conteo_frecuencias = df.value_counts()
df_frecuencias = conteo_frecuencias.to_frame()
df_frecuencias.reset_index(inplace = True)
df_frecuencias.columns = ['token', 'conteo']
df_frecuencias.head(20)
# Out:
#       token  conteo
# 0     whale     950
# 1       one     890
# 2      like     575
# 3      upon     565
# 4       old     440
# 5       man     435
# 6     would     427
# 7        ye     420
# 8      ahab     416
# 9    whales     396
# 10     ship     384
# 11      sea     379
# 12   though     364
# 13      yet     339
# 14     time     323
# 15     long     313
# 16  chapter     308
# 17    still     307
# 18    great     305
# 19     said     294

# %%
from nltk.stem import LancasterStemmer

ls = LancasterStemmer()

stemmed_words = [ls.stem(palabra) for palabra in tokens]
# Conteo de frecuencias usando la técnica stem
df_stemmed = pd.DataFrame(stemmed_words)
conteo_frecuencias_stem = df_stemmed.value_counts().to_frame()
conteo_frecuencias_stem.reset_index(inplace = True)
conteo_frecuencias_stem.columns = ['token', 'conteo']
conteo_frecuencias_stem.head(20)
# Out:
#      token  conteo
# 0     whal    1539
# 1       on     920
# 2      lik     594
# 3     upon     565
# 4      man     558
# 5     ship     558
# 6       ye     499
# 7     ahab     494
# 8     seem     469
# 9      sea     468
# 10     old     443
# 11     tim     438
# 12      ev     433
# 13   would     427
# 14    boat     423
# 15      us     365
# 16  though     364
# 17     yet     339
# 18    hand     339
# 19    long     337
